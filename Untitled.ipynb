# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotx
from matplotlib.ticker import FormatStrFormatter
# %matplotlib notebook

# %%
dimsumdict = {"1": 5320.067084721837, "121": 2362.732650034929, "441": 320.33839098975426,
              "961": 586.1781463587785, "1681": 228.51335684620744, "2601": 696.3406056686003,
              "3721": 160.68934873566388, "5041": 338.4095221838987, "6561": 296.85684568374023, 
              "8281": 123.04956018438209, "10112": 117.08416851931479, "20224": 108.61028456181795, "30336": 99.08472684070368, "40448": 4.16318828051938, "50560": 111.30317410817874, "60672": 68.24019820520068, "70784": 59.63294640400209, "80896": 49.61086483558124, "91008": 1.0199003049897526, "101120": 1.7046905097693368, "111232": 4.4410049032826226e-14}

# %%
x = dimsumdict.keys()

# %%
# plot
fig, ax = plt.subplots()

y = dimsumdict.values()
x = dimsumdict.keys()
ax.plot(x, y, linewidth=2.0)
plt.xticks(rotation=45, ha='right')

plt.xlabel("Gamma")
plt.ylabel("RMSE")
plt.title("DIMSUM Curve")


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7499809339648">

# %%
bgd_test_acc = {"1": 3.4650229765550633, "2": 3.455474377610334, "3": 3.45413287618772, "4": 3.4449775663817364, "5": 3.4542284236603886, "6": 3.4542062479444033, "7": 3.43014815609701, "8": 3.4491356674171496, "9": 3.449252853349836, "10": 3.45073660151614, "11": 3.473234411429382, "12": 3.471697782190699, "13": 3.4715053511230356, "14": 3.4716356323155426, "15": 3.4722296831478623, "16": 3.474786234657377, "17": 3.477099880979967, "18": 3.476980589698538, "19": 3.477056877519574, "20": 3.4770994003284312, "21": 3.47712441803899}
sgd_test_acc = {"1": 3.4800008747189093, "2": 3.479156866946107, "3": 3.478890845650467, "4": 3.4761081979389603, "5": 3.476854714438649, "6": 3.4768089422457296, "7": 3.4552585584867264, "8": 3.4569629747652257, "9": 3.4570278180024596, "10": 3.4579456183479804, "11": 3.4794889860570977, "12": 3.4785717650857175, "13": 3.4784085930214665, "14": 3.478538476566708, "15": 3.478667382078286, "16": 3.479159443417766, "17": 3.47928556174226, "18": 3.479228432071006, "19": 3.479287542084821, "20": 3.479271454639868, "21": 3.47920808336812}
fig, ax = plt.subplots()

y = bgd_test_acc.values()
x = bgd_test_acc.keys()
ax.plot(x, y, linewidth=2.0, label="bgd")
plt.xticks(rotation=45, ha='right')

y = sgd_test_acc.values()
x = sgd_test_acc.keys()
ax.plot(x, y, linewidth=2.0, label="SGD")

plt.legend()

plt.xlabel("K")
plt.ylabel("Test RMSE")
plt.title("BGD and SGD Test Accuracy with different values of K")


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7499809339648">

# %%
y = sgd_test_acc.values()
x = sgd_test_acc.keys()
ax.plot(x, y, linewidth=2.0)
plt.xticks(rotation=45, ha='right')

plt.xlabel("K")
plt.ylabel("Test RMSE")
plt.title("Sgd Test Accuracy with different values of K")


plt.show()

# %%
bgd_dict = {
}

# %%
# plot
fig, ax = plt.subplots()
x = range (1, 31)
plt.figure()

key2 = 8
y2 = np.array(sgd_dict[key2])
plt.subplot(311)
plt.plot(x, y2, linewidth=1.0,label=" sgd k = {}".format(key2))
plt.legend(loc='best')
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.suptitle('SGD VS BGD RMSE with 30 epochs and K = {}'.format(key2))

plt.subplot(312)


y2 = np.array(bgd_dict[key2])
plt.plot(x, y2, linewidth=1.0,label="bgd k  = {}".format(key2))
plt.legend(loc='best')
plt.xlabel("Epoch")
plt.ylabel("RMSE")



plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7499809339648">
# <img src="data:image/png;base64,..." width="639.7499809339648">

# %%
# plot
fig, ax = plt.subplots()
x = range (1, 31)
plt.figure()

key2 = 12
y2 = np.array(sgd_dict[key2])
plt.subplot(311)
plt.plot(x, y2, linewidth=1.0,label=" sgd k = {}".format(key2))
plt.legend(loc='best')
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.suptitle('SGD RMSE with 30 epochs and of K = {}'.format(key2))




plt.subplot(312)
y2 = np.array(bgd_dict[key2])
plt.plot(x, y2, linewidth=1.0,label="bgd k  = {}".format(key2))
plt.legend(loc='best')
plt.xlabel("Epoch")
plt.ylabel("RMSE")



plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7499809339648">
# <img src="data:image/png;base64,..." width="639.7499809339648">

# %%
# plot
fig, ax = plt.subplots()
x = range (1, 31)
plt.figure()

key2 = 16
y2 = np.array(sgd_dict[key2])
plt.subplot(311)
plt.plot(x, y2, linewidth=1.0,label=" sgd k = {}".format(key2))
plt.legend(loc='best')
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.suptitle('SGD RMSE with 30 epochs and of K = {}'.format(key2))




plt.subplot(312)
y2 = np.array(bgd_dict[key2])
plt.plot(x, y2, linewidth=1.0,label="bgd k  = {}".format(key2))
plt.legend(loc='best')
plt.xlabel("Epoch")
plt.ylabel("RMSE")



plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7499809339648">
# <img src="data:image/png;base64,..." width="639.7499809339648">

# %%
# plot
fig, ax = plt.subplots()
x = range (1, 31)
plt.figure()

key2 = 4
y2 = np.array(sgd_dict[key2])
plt.subplot(311)
plt.plot(x, y2, linewidth=1.0,label=" sgd k = {}".format(key2))
plt.legend(loc='best')
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.suptitle('SGD RMSE with 30 epochs and of K = 4')




key2 = 4
plt.subplot(312)
y2 = np.array(bgd_dict[key2])
plt.plot(x, y2, linewidth=1.0,label="bgd k  = {}".format(key2))
plt.legend(loc='best')
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.suptitle('SGD vs BGD RMSE with 30 epochs and of K = 4')



plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7499809339648">
# <img src="data:image/png;base64,..." width="959.9999713897713">

# %%
# plot


fig, ax = plt.subplots()
x = range (1, 31)

key2 = 10
y2 = np.array(bgd_dict[key2])
ax.plot(x, y2, linewidth=1.0,label="bgd k = {}".format(key2))
matplotx.line_labels()
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.suptitle('RMSE with 30 epochs and different values of K')

y2 = np.array(sgd_dict[key2])
ax.plot(x, y2, linewidth=1.0,label="sgd k = {}".format(key2))
matplotx.line_labels()
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.suptitle('RMSE with 30 epochs and different values of K')


key2 = 1
y2 = np.array(bgd_dict[key2])
ax.plot(x, y2, linewidth=1.0,label=" bgd k = {}".format(key2))
matplotx.line_labels()
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.suptitle('RMSE with 30 epochs and different values of K')

y2 = np.array(sgd_dict[key2])
ax.plot(x, y2, linewidth=1.0,label=" sgd k = {}".format(key2))
matplotx.line_labels()
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.suptitle('RMSE with 30 epochs and different values of K')


key2 = 5
y2 = np.array(bgd_dict[key2])
ax.plot(x, y2, linewidth=1.0,label="bgd k = {}".format(key2))
matplotx.line_labels()
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.suptitle('RMSE with 30 epochs and different values of K')

y2 = np.array(sgd_dict[key2])
ax.plot(x, y2, linewidth=1.0,label="sgd k = {}".format(key2))
matplotx.line_labels()
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.suptitle('RMSE with 30 epochs and different values of K')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7499809339648">

# %%
fig, ax = plt.subplots()
x = range (1, 31)
plt.figure()
plt.subplot(1,3,1)
for key, values in sgd_dict.items():
    if key%2 == 0:
        y2 = np.array(values)
        plt.plot(x, y2, linewidth=1.0,label=" sgd k = {}".format(key))
        matplotx.line_labels()

        plt.xlabel("Epoch")
        plt.ylabel("RMSE")
        plt.suptitle('SGD vs. BGD RMSE with 30 epochs and different values of K')

plt.subplot(1,3,3)

for key, values in bgd_dict.items():
    if key%2 == 0:
        y2 = np.array(values)
        plt.plot(x, y2, linewidth=1.0,label=" bgd k = {}".format(key))
        matplotx.line_labels()

        plt.xlabel("Epoch")
        plt.ylabel("RMSE")
        plt.suptitle('SGD vs. BGD RMSE with 30 epochs and different values of K')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7499809339648">
# <img src="data:image/png;base64,..." width="928.4999723285445">

# %%
fig, ax = plt.subplots()
x = range (1, 31)
plt.figure()

for key, values in bgd_dict.items():
    for key2, values2 in bgd_dict.items():
        if key%4 == 0:
            if key2%4 == 0:
                y2 = np.array(values)
                plt.plot(x, y2, linewidth=1.0,label=" sgd k = {}".format(key))
                matplotx.line_labels()

                y2 = np.array(values2)
                plt.plot(x, y2, linewidth=1.0,label=" sgd k = {}".format(key))
                matplotx.line_labels()

                plt.xlabel("Epoch")
                plt.ylabel("RMSE")
                plt.suptitle('BGD RMSE with 30 epochs and different values of K')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7499809339648">
# <img src="data:image/png;base64,..." width="639.7499809339648">
